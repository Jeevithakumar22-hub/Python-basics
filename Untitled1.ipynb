# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeevithakumar22-hub/Python-basics/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("You are eligible for voting")
else:
    print("You are not eligible for voting")
# Out:
# Enter your age: 18
# You are eligible for voting

# %%
marks = int(input("Enter student marks: "))

if marks < 50:
    marks = marks + 10
    print("Grace marks added.")
    print("Updated Marks:", marks)
else:
    print("Pass")
# Out:
# Enter student marks: 45
# Grace marks added.
# Updated Marks: 55
